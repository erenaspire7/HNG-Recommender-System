# %%
#importing relevant modules
import pandas as pd
import mysql.connector
from sqlalchemy import create_engine

# %%
#loading the dataset
mydb = mysql.connector.connect(host="remotemysql.com",
                              user="8SawWhnha4",
                              passwd="zFvOBIqbIz",
                              database="8SawWhnha4")

engine = create_engine('mysql+mysqlconnector://8SawWhnha4:zFvOBIqbIz@remotemysql.com/8SawWhnha4')

# %%
#fetching the tables in the dataset
dbcursor = mydb.cursor()
dbcursor.execute('show tables')
for table in dbcursor:
    print(table)
# Out:
# ('comments',)
# ('contact_settings',)
# ('ext_feed_banks',)
# ('ext_rsses',)
# ('extfeeds',)
# ('following',)
# ('interests',)
# ('maillists',)
# ('migrations',)
# ('notifications',)
# ('password_resets',)
# ('posts',)
# ('thoughts',)
# ('user_settings',)
# ('users',)
# ('users_email_login_tokens',)

# %% [markdown]
# # EXPLOARTOY DATA ANALYSIS

# %%
#checking ou the comments table
comments = pd.read_sql_query('select * from comments', engine)
comments
# Out:
# Empty DataFrame
# Columns: [id, post_id, user_id, comment, created_at, updated_at]
# Index: []

# %%
#checking out the contact_settings table
contact_settings = pd.read_sql_query('select * from contact_settings', engine)
contact_settings
# Out:
#       id  user_id                               email  \
# 0      1       78         emmanuelezenwigbo@gmail.com
# 1      2       90                  dward009@gmail.com
# 2      3       53                   apeji93@gmail.com
# 3      4      133                 ireabueke@gmail.com
# 4      5       92                 bindas.fs@gmail.com
# 5      6      138                 detounmed@gmail.com
# 6      7      130               okakosomano@gmail.com
# 7      8      177                   mubbs24@gmail.com
# 8      9       73          charlesokoliocha@gmail.com
# 9     10      160            olaitanaderoju@gmail.com
# 10    11      123                geomaggi91@gmail.com
# 11    12      120                 iburity19@gmail.com
# 12    13      121                 chubukass@gmail.com
# 13    14      142               reeta.nzere@gmail.com
# 14    15       81               davidadigwu@gmail.com
# 15    16      150              calabarspice@gmail.com
# 16    17      238            eyubechristian@gmail.com
# 17    18      220                corperevon@gmail.com
# 18    19       62               giftomodu20@gmail.com
# 19    20      143            siyanbolafaruk@gmail.com
# 20    21      131            onwujiubaugouo@gmail.com
# 21    22       77  oiadebayo11@student.lautech.edu.ng
# 22    23      173              onsearinahud@gmail.com
# 23    24       70              josephachonu@gmail.com
# 24    25       47                       hi@meedul.com
# 25    26      218              aphatheology@gmail.com
# 26    27      175               rajilat1000@gmail.com
# 27    28      255                shodiyaade@gmail.com
# 28    29      115                jemimah.vb@gmail.com
# 29    30      258               sootersaalu@gmail.com
# ..   ...      ...                                 ...
# 219  220     1754           mariamadebola28@gmail.com
# 220  221      534         ayobamiolugboyega@gmail.com
# 221  222     1776                egbobright@gmail.com
# 222  223     1802                musaharold@gmail.com
# 223  224     1808           rutherford.ejim@gmail.com
# 224  225     1818                lateef9816@gmail.com
# 225  226     1122                odekunlejj@gmail.com
# 226  227     1844          amadiprecious899@gmail.com
# 227  228      691         tiberiusmairura90@gmail.com
# 228  229      707             othanksgiving@gmail.com
# 229  230     1007               unuebhojude@gmail.com
# 230  231     1904        adebayorilerioluwa@gmail.com
# 231  232      666                 etolope94@gmail.com
# 232  233     1915                   ucshaya@gmail.com
# 233  234     1921               ihekwoabamn@gmail.com
# 234  235     1220          osisindu.awesome@gmail.com
# 235  236     1946                 anthony@osawere.com
# 236  237     1977                   tabafor@gmail.com
# 237  238      577                 mashdon77@gmail.com
# 238  239       20                albertoboh@yahoo.com
# 239  240     1798                    iamduq@gmail.com
# 240  241      799         ifeoluwagodishere@gmail.com
# 241  242     2065                akinsondan@gmail.com
# 242  243     2112                tosine1790@gmail.com
# 243  244     1543               lindalily50@gmail.com
# 244  245     2098             fortunereal90@gmail.com
# 245  246     2143           idrisade.eedris@gmail.com
# 246  247     2150                  tbitopsi@gmail.com
# 247  248     2256             oluwadarasiwa@gmail.com
# 248  249     2263          popoolaolusola92@gmail.com
#
#                                        display_message created_at updated_at
# 0                     Web Developer | Digital Marketer       None       None
# 1                                              Call me       None       None
# 2                                                Yossi       None       None
# 3                                                 None       None       None
# 4                             Contact me on that email       None       None
# 5                                         LUCID Tester       None       None
# 6                                 Hit me up, whenever.       None       None
# 7                                           Call me on       None       None
# 8                           Send a mail.\r\n\r\nThanks       None       None
# 9            Wanna know more?\r\n\r\nreach out anytime       None       None
# 10                           Adeniran Margaret Adenike       None       None
# 11                                                None       None       None
# 12               Coding is the new food\r\n08066702567       None       None
# 13                                             All set       None       None
# 14                                                None       None       None
# 15                                                None       None       None
# 16                                        Phone number       None       None
# 17   Hello people. \r\n\r\nYou are welcome to me bl...       None       None
# 18                                           Reach out       None       None
# 19                       Follow me on twitter @siyfa00       None       None
# 20                                                None       None       None
# 21                                        Display text       None       None
# 22                                              Remote       None       None
# 23                           keep your messages coming       None       None
# 24             twitter: @ubarab\r\nweb: www.meedul.com       None       None
# 25   You can also get to me through Whatsapp: 08107...       None       None
# 26                                                None       None       None
# 27                                                 ME!       None       None
# 28                                                None       None       None
# 29   #lucidfeedback\r\n\r\nI can't edit my username...       None       None
# ..                                                 ...        ...        ...
# 219                                        maryam_bola       None       None
# 220                                               None       None       None
# 221                                 Learning to create       None       None
# 222           The earth is for US tot explore.........       None       None
# 223  Email: rutherford.ejim@gmail.com\r\nWhatsapp: ...       None       None
# 224                                   My Email Address       None       None
# 225                                               None       None       None
# 226                        Curiosity is Life itself???       None       None
# 227  It is about what you think about yourself that...       None       None
# 228                                                Hey       None       None
# 229                       Phone number: +2348076568004       None       None
# 230                                               None       None       None
# 231                                               None       None       None
# 232                                    At your service       None       None
# 233                                               None       None       None
# 234                   Follow me on Twitter: @Awesocode       None       None
# 235  Osawere O. Anthony\r\nCreative Developer, Brux...       None       None
# 236                  This is my primary contact email.       None       None
# 237                                    Talk to Marshal       None       None
# 238                                               None       None       None
# 239                                 Twitter.com/theduq       None       None
# 240                                  Ifeoluwa Oyekanmi       None       None
# 241                                        Nice design       None       None
# 242                                              O2bid       None       None
# 243                                              Linda       None       None
# 244                            Your blogging superhero       None       None
# 245  Hi, I'm Idris Idris, a python developer (begin...       None       None
# 246                              Whatsapp: 07031213263       None       None
# 247                                               None       None       None
# 248                                             Popson       None       None
#
# [249 rows x 6 columns]

# %%
#checking out the ext_feed_banks table
ext_feed_banks = pd.read_sql_query('select * from ext_feed_banks', engine)
ext_feed_banks
# Out:
# Empty DataFrame
# Columns: [id, site, site_image, title, des, link, date, image, created_at, updated_at]
# Index: []

# %%
#checking out the ext_rsses table
ext_rsses = pd.read_sql_query('select * from ext_rsses', engine)
ext_rsses
# Out:
# Empty DataFrame
# Columns: [id, user_id, title, url, description, image, link, lastBuildDate, created_at, updated_at, category]
# Index: []

# %%
#checking out the following table
following = pd.read_sql_query('select * from following', engine)
following
# Out:
#       my_id  follower_id  status
# 0         3            6       1
# 1         6            3       1
# 2         3            2       1
# 3         3            7       1
# 4         7            2       1
# 5         7            3       1
# 6         9            2       1
# 7         9            3       1
# 8         9            7       1
# 9         8            9       1
# 10        4            9       1
# 11        3            9       1
# 12        1            7       1
# 13        1            3       1
# 14        4            2       1
# 15        4            1       1
# 16        3            2       1
# 17        3            1       1
# 18       11            7       1
# 19        7           11       1
# 20       17            7       1
# 21       20            7       1
# 22       20            3       1
# 23       20            9       1
# 24       23            7       1
# 25       25            7       1
# 26       26            7       1
# 27       28            7       1
# 28       39            7       1
# 29        3           20       1
# ...     ...          ...     ...
# 5266   1212            6       0
# 5267    475            6       0
# 5268    475            6       0
# 5269    327            6       0
# 5270    955            6       0
# 5271    352            6       0
# 5272    352            7       0
# 5273   1836            6       0
# 5274    653            6       0
# 5275    329            6       0
# 5276    891            6       0
# 5277    945            6       0
# 5278    168            6       0
# 5279    143            6       0
# 5280    361            6       0
# 5281    361            6       0
# 5282   2287            6       0
# 5283     47          535       0
# 5284   1101          326       0
# 5285   1199            6       0
# 5286   1439         1047       0
# 5287   1439         1926       0
# 5288   2282            6       0
# 5289   2282            6       0
# 5290   2228          326       0
# 5291     24            7       0
# 5292    916            6       0
# 5293      4           29       0
# 5294     29            4       0
# 5295     34            2       0
#
# [5296 rows x 3 columns]

# %%
#checking out the interests table
interests = pd.read_sql_query('select * from interests', engine)
interests
# Out:
# Empty DataFrame
# Columns: [id, interest, cover_img, created_at, updated_at]
# Index: []

# %%
#checking out the maillists table
maillists = pd.read_sql_query('select * from maillists', engine)
maillists
# Out:
#     id                           email created_at updated_at
# 0    1               ubarab85@live.com       None       None
# 1    2            detoun4med@gmail.com       None       None
# 2    3              emmanuel@gmail.com       None       None
# 3    4              ifydechu@gmail.com       None       None
# 4    5         olaiwolaahmod@gmail.com       None       None
# 5    6        francosino5662@gmail.com       None       None
# 6    7          phemmylintry@gmail.com       None       None
# 7    8     mololuwaakintunde@gmail.com       None       None
# 8    9              idyekpoh@gmail.com       None       None
# 9   10            durabuildr@gmail.com       None       None
# 10  11     akomolafeayoyinka@gmail.com       None       None
# 11  12              ogbole12@gmail.com       None       None
# 12  13        barbaramangiri@gmail.com       None       None
# 13  14                stelroy100@gmail       None       None
# 14  15                stelroy100@gmail       None       None
# 15  16                   stelroy100@gm       None       None
# 16  17            stelroy100@gmail.com       None       None
# 17  18                   stelroy100@gm       None       None
# 18  19                   stelroy100@gh       None       None
# 19  20             ibrolad89@gmail.com       None       None
# 20  21         olaiya.adeolu@gmail.com       None       None
# 21  22            oshunboteo@gmail.com       None       None
# 22  23       jolaiyaemmanuel@gmail.com       None       None
# 23  24         albert.osekre@gmail.com       None       None
# 24  25       harunageorge829@gmail.com       None       None
# 25  26            unoaffiong@gmail.com       None       None
# 26  27            decele2011@gmail.com       None       None
# 27  28        nnabuiheizunna@gmail.com       None       None
# 28  29              bgbiri92@gmail.com       None       None
# 29  30       malikoabdulaziz@gmail.com       None       None
# 30  31       w.olamideesther@gmail.com       None       None
# 31  32          championspi9@gmail.com       None       None
# 32  33             atulewins@gmail.com       None       None
# 33  34  ejioforonyinyechukwu@gmail.com       None       None
# 34  35          Otururebecca@gmail.com       None       None
# 35  36          jolarchibong@gmail.com       None       None
# 36  37           cecilesirri@gmail.com       None       None
# 37  38     preciousayovunefe@gmail.com       None       None
# 38  39          mattidungafa@gmail.com       None       None
# 39  40           prince@mailinator.com       None       None
# 40  41           prince@mailinator.com       None       None

# %%
#checking out the migrations table
migrations = pd.read_sql_query('select * from migrations', engine)
migrations
# Out:
#     id                                          migration  batch
# 0    1               2014_10_12_000000_create_users_table      1
# 1    2     2014_10_12_100000_create_password_resets_table      1
# 2    4             2019_07_10_143908_create_ext_rss_table      1
# 3    5            2019_07_10_145904_create_extfeeds_table      1
# 4    6     2019_07_26_080545_add_short_bio_to_users_table      1
# 5    7          2019_08_16_204047_create_contact_settings      2
# 6    8           2019_08_18_092103_create_maillists_table      2
# 7    9               2019_08_21_100613_create_posts_table      3
# 8   10               2019_08_21_193424_add_image_to_posts      3
# 9   11            2019_08_22_115308_create_comments_table      3
# 10  12            2019_08_23_124434_create_thoughts_table      3
# 11  13       2019_08_23_124615_create_notifications_table      3
# 12  14    2019_08_23_125853_add__status_id_to_posts_table      3
# 13  15        2019_08_23_130039_add_action_to_posts_table      3
# 14  16           2019_08_24_212810_create_following_table      3
# 15  17             2019_08_26_130908_add_tags_to_extfeeds      4
# 16  18           2019_08_31_102700_create_interests_table      5
# 17  23       2019_09_02_033813_add_post_id_to_posts_table      6
# 18  24  2019_09_12_163927_create_users_email_login_tok...      6
# 19  26       2019_07_08_124817_create_user_settings_table      7
# 20  27  2019_09_20_092624_add_tabs_to_user_settings_table      7
# 21  28  2019_09_20_092826_add_view_to_user_settings_table      8
# 22  29  2019_09_20_092914_add_theme_to_user_settings_t...      9
# 23  30  2019_09_20_094422_add_public_view_to_user_sett...      9
# 24  31  2019_09_22_095822_add_category_to_ext_rsses_table      9
# 25  32      2019_09_22_172650_create_ext_feed_banks_table      9

# %%
#checking out the notifications table
notifications = pd.read_sql_query('select * from notifications', engine)
notifications
# Out:
#       id  post_id  parent_comment_id  \
# 0      1      NaN                NaN
# 1      2      NaN                NaN
# 2      3      NaN                NaN
# 3      5      NaN                NaN
# 4      7    278.0                NaN
# 5      8    360.0                NaN
# 6      9    360.0                NaN
# 7     10      NaN                NaN
# 8     11    143.0                NaN
# 9     12    371.0                NaN
# 10    13      NaN                NaN
# 11    14      NaN                NaN
# 12    15    371.0                NaN
# 13    16    371.0                NaN
# 14    17      NaN                NaN
# 15    18      NaN                NaN
# 16    19      NaN                NaN
# 17    20      NaN                NaN
# 18    21      NaN                NaN
# 19    22      NaN                NaN
# 20    23      NaN                NaN
# 21    24      NaN                NaN
# 22    25      NaN                NaN
# 23    26    371.0                NaN
# 24    27      NaN                NaN
# 25    28      NaN                NaN
# 26    29      NaN                NaN
# 27    30      NaN                NaN
# 28    31      NaN                NaN
# 29    32      NaN                NaN
# ..   ...      ...                ...
# 160  171    993.0                NaN
# 161  172    993.0                NaN
# 162  173    996.0                NaN
# 163  174    996.0                NaN
# 164  175    998.0                NaN
# 165  177    998.0                NaN
# 166  178    995.0                NaN
# 167  179    998.0                NaN
# 168  180    999.0                NaN
# 169  181    998.0                NaN
# 170  182    998.0                NaN
# 171  183    993.0                NaN
# 172  184    998.0                NaN
# 173  185   1007.0                NaN
# 174  186   1007.0                NaN
# 175  187   1007.0              186.0
# 176  188   1007.0              186.0
# 177  189    998.0              182.0
# 178  190   1002.0                NaN
# 179  191   1002.0              190.0
# 180  193    993.0                NaN
# 181  194    983.0                NaN
# 182  195    983.0                NaN
# 183  197    985.0                NaN
# 184  198    985.0                NaN
# 185  199    999.0                NaN
# 186  202   1007.0                NaN
# 187  216    998.0                NaN
# 188  219    999.0                NaN
# 189  222    998.0                NaN
#
#                                                comment  sender_id  user_id  \
# 0                                                 None          4        7
# 1                                                 None          1        4
# 2                                                 None          3       45
# 3                                                 None          1        4
# 4                                             Hey bro!          1        4
# 5    This is an interesting write-up. I have a ques...          3        7
# 6                                      A nice write up          4        7
# 7                                                 None          3      363
# 8    I have learnt how to publish an article and Ho...       2191     2191
# 9                                       That's awesome          9        3
# 10                                                None        834      856
# 11                                                None       2240       59
# 12                                   wait, this works?          6        3
# 13                                uhm... not really...          6        3
# 14                                                None        492        6
# 15                                                None       2245        6
# 16                                                None       1051        6
# 17                                                None        710        6
# 18                                                None       1043       11
# 19                                                None        868        6
# 20                                                None        612        6
# 21                                                None        847        6
# 22                                                None       1731        6
# 23   But my posts are nowhere to be found. Excellen...        489        3
# 24                                                None        242        6
# 25                                                None       1864     1147
# 26                                                None       1864      118
# 27                                                None        439     2218
# 28                                                None        439     2218
# 29                                                None        192        6
# ..                                                 ...        ...      ...
# 160                                               None         34        2
# 161                                               None         34        2
# 162                                               None          3        1
# 163                                               None          3        1
# 164                                               None          9        2
# 165                                               None          3        2
# 166                                               None          3        1
# 167                      i wish there was smthn better          2        2
# 168                                               Good          4        4
# 169                                               Test          3        2
# 170                                       Another test          3        2
# 171                                                 Hi          2        2
# 172                                            all set          2        2
# 173                                               test          3        3
# 174                                              testt          3        3
# 175                                               test          3        3
# 176                                              testr          3        3
# 177                                         Oya tester          4        3
# 164       1       Like   Reaction 2019-09-02 15:56:51 2019-09-02 16:38:17
# 165       1       Love   Reaction 2019-09-03 02:25:12 2019-09-04 13:29:22
# 166       1       Love   Reaction 2019-09-03 02:25:57 2019-09-07 14:44:46
# 167       1  Commented       Post 2019-09-04 13:37:44 2019-09-07 14:44:55
# 168       1  Commented       Post 2019-09-05 10:24:34 2019-09-05 16:20:09
# 169       1  Commented       Post 2019-09-05 11:37:26 2019-09-07 14:44:55
# 170       1  Commented       Post 2019-09-05 11:37:34 2019-09-07 14:44:55
# 171       1  Commented       Post 2019-09-05 12:50:42 2019-09-07 14:44:55
# 172       1  Commented       Post 2019-09-05 16:16:13 2019-09-07 14:44:55
# 173       0  Commented       Post 2019-09-06 18:40:19 2019-09-06 18:40:19
# 174       0  Commented       Post 2019-09-06 18:40:24 2019-09-06 18:40:24
# 175       0    Replied       Post 2019-09-06 18:40:29 2019-09-06 18:40:29
# 176       0    Replied       Post 2019-09-06 18:40:38 2019-09-06 18:40:38
# 177       0    Replied       Post 2019-09-07 09:33:29 2019-09-07 09:33:29
# 178       0  Commented       Post 2019-09-07 09:43:20 2019-09-07 09:43:20
# 179       0    Replied       Post 2019-09-07 09:43:38 2019-09-07 09:43:38
# 180       1       Like   Reaction 2019-09-07 14:30:13 2019-09-07 14:44:55
# 181       1       Like   Reaction 2019-09-07 14:30:15 2019-09-07 14:44:55
# 182       1       Love   Reaction 2019-09-07 14:30:16 2019-09-07 14:44:55
# 183       1       Like   Reaction 2019-09-07 14:30:25 2019-09-07 14:44:55
# 184       1       Love   Reaction 2019-09-07 14:30:26 2019-09-07 14:44:55
# 185       1       Like   Reaction 2019-09-07 14:44:58 2019-09-07 16:48:04
# 186       0       Like   Reaction 2019-09-07 14:45:08 2019-09-07 14:45:08
# 187       0       Like   Reaction 2019-09-07 16:33:27 2019-09-07 16:33:27
# 188       1       Like   Reaction 2019-09-07 17:11:26 2019-09-19 12:18:38
# 189       0       Love   Reaction 2019-09-07 17:11:41 2019-09-07 17:11:41
#
# [190 rows x 11 columns]

# %%
#checking out the password_reset table
password_resets = pd.read_sql_query('select * from password_resets', engine)
password_resets
# Out:
# Empty DataFrame
# Columns: [email, token, created_at]
# Index: []

# %%
#checking out the password_reset table
posts = pd.read_sql_query('select * from posts', engine)
posts
# Out:
#        id  user_id                                              title  \
# 0       1     2077                  What i have learnt so far on HTML
# 1       2     1719                                   HTML BEGINS HERE
# 2       4     1310                            My Laziness In The Open
# 3       6     1787                                          MY TASK 2
# 4       7      167                                             Task 2
# 5       8      329                                 My Journey on HTML
# 6       9     2040                            StartNG HTML Exposition
# 7      11     1787                                          MY TASK 2
# 8      12     2040                                  StartNG HTML task
# 9      13     2040                          On StartNG Pre-Internship
# 10     15      942                                                why
# 11     16      329                                        Please note
# 12     20     2151                      HNG internship journey so far
# 13     21      352                                 What I done so far
# 14     23     2153                          Learnt Learn and Learning
# 15     24     2158                Learning Web development at StartNg
# 16     25       54  The Journey with StartNG: Creating my CV with ...
# 17     26      619                What i have done so far on start.ng
# 18     27      619                                      Task Number 7
# 19     29     1487                       What has been learnt so far?
# 20     30      225                    WHAT I HAVE DONE SO FAR ON HTML
# 21     32     1008                                             TASK 2
# 22     33     1442                           CURRICULUM VITAE IN HTML
# 23     34     2102                                HNG start.ng Task 2
# 24     35      146                                          kikkymakz
# 25     36     2156                                   StartNg Task One
# 26     37     1929                                 The Journey so far
# 27     39      888                          HTML: The journey so far.
# 28     40     2159                    Public Journal :task 2. HTML CV
# 29     41      231                                   My CV using HTML
# ..    ...      ...                                                ...
# 846   967     1120                        CSS (cascading style sheet)
# 847   968      843                 CSS has added beauty to my webpage
# 848   969     1910                                 MY HTML EXPERIENCE
# 849   970     1910                         ELLA'S START-NG EXPERIENCE
# 850   980       29                                         Post title
# 851   981        2                                          html test
# 852   982        2                YOUR HIGH IQ WILL KILL YOUR STARTUP
# 853   983        2  A CHINESE VILLAGER WHO SELLS MORE SOFTWARE DAI...
# 854   984        2              BUILD AROUND YOUR DISCOVERY MECHANISM
# 855   985        2                    DON'T ASK WHY YOU WERE REJECTED
# 856   986        2                                      THE SUNFLOWER
# 857   987        2                                   Welcome to Lucid
# 858   988        2                                      This is lucid
# 859   989        2                                this is a test post
# 860   991        5                               Post with two images
# 861   992        2                                       this is mine
# 862   993        2                               Your face PHP script
# 863   994        1                                              First
# 864   995        1                                             second
# 865   996        1                                              third
# 866   998        2                                       with picture
# 867   999        4                                               TEst
# 868  1000       22                                               asda
# 869  1001       22                                     Speed Of Light
# 870  1002       22                                              Am ok
# 871  1003       45                                          jbhjkhkbb
# 872  1004        3                 Testing tags and really long posts
# 873  1005        3                                      Testing image
# 874  1006        3                                               Test
# 875  1007        3                                      My first post
#
#                                                content  \
# 0    I learnt how to use the table tag as i have us...
# 1     I am on this journey with start.ng, and here ...
# 2    I have not been attending classes on the HNG c...
# 3    My journey on **StartNG** pre-internship progr...
# 4     A Summary on The “idongesit.html” CV, Its Str...
# 5    Using the Hyper Text Markup Language (HTML) ha...
# 6    ![](/storage/2040/images/img-kf6sy3kvg0.png)![...
# 7    My journey on **StartNG** pre-internship progr...
# 8    <p> </p>\n<p>I have learned a lot about HTML a...
# 9    **What I have learned so far**\n\nI have learn...
# 10                                        lucid why na
# 11   The screenshot of my HTML CV attached to my la...
# 12   So far on the HNG pre-internship we've been ab...
# 13   I have learnt about html tags, heading, the ve...
# 14   So far into the world of technologies I've bee...
# 15   With this opportunity brought to me by StartNg...
# 16   In my previous post, I talked about all the in...
# 17   <p>When I embarked on this internship, i would...
# 18   <p><strong>What I have learnt so far:</strong>...
# 19   It has been an interesting journey so far, hav...
# 20   ![](/storage/225/images/img-5y3zt92b66.png)Wha...
# 21   HI GUYS\n-------\n\nOn the previous post I tal...
# 22   Exploring the possibilities that exists in the...
# 23   The second task that was alloted to us (the pr...
# 24   1.  Achieveing this was a huge success on my p...
# 25   **What i have learnt so far:**\n\n> I have lea...
# 26   I just created my first html page guys!!!!!! I...
# 27   HTML (HyperText Markup Language) is a language...
# 28   firstly I cant find my previous entry. My firs...
# 29   This week's task opened my eyes to a possibili...
# ..                                                 ...
# 846  CSS (cascading style sheet)\n\nCss is used for...
# 847  Working with html alone can not guarantee the ...
# 848  <p>I have gotten to the second stage of my pre...
# 849  <p><strong>To be honest, how did I get here? S...
# 850  <p><img src="/storage/lucidowner.test/images/i...
# 851  \`html\`\n\n  \n\n\`<!DOCTYPE html>\n\n<html l...
# 852  <p>In 2004 I was in Brazil, walking down the h...
# 853  <p>I was alone in the center of a small Chines...
# 854  <p>When you launch your web application, deskt...
# 855  <p>I’ve noticed something that is not immediat...
# 856  <p>A field of sunflowers sat beside another fi...
# 857           <p>Here You Get the Best of Blogging</p>
# 858                             <p>I love this app</p>
# 859                         <p>i need this to work</p>
# 860  Here and now man\n\n![](/storage/5/images/img-...
# 861                                               mine
# 862  this is what you see\n\n\~~~php\n\n<?php echo ...
# 863                                              First
# 864    second![](/storage/1/images/img-ga0dlp954u.png)
# 865  third![](/storage/1/images/img-hta9olnjij.png)...
# 866         ![](/storage/2/images/img-rw5rbxsjg4.jpeg)
# 867  jnlkj\r\n\r\n  \r\n\r\n![](/storage/4/images/i...
# 868  <p><img src="/storage/godspeed.gp/images/img-m...
# 869  <p><img src="/storage/godspeed.gp/images/img-q...
# 870   let's do this ooooooooooooooo edit and bee fixed
# 871                    jkhbjilbjhb v hvhjbv h hbv jhkv
# 872  <p>Testing tags and really long posts.</p>\n<p...
# 873  <p>Test if image works</p>\n<p><img src="/stor...
# 874  <p><img src="/storage/jeff.ogah/images/img-x89...
# 875  <p>About time I made one.</p>\n<p><strong>Bold...
#
#                                                   tags  \
# 0                                                 None
# 1                                           Technology
# 2                                                 None
# 3                                                 None
# 4                                                 None
# 5                                                 None
# 6                                                 None
# 7                                                 html
# 8
# 9    StartNG pre-internship, Developer, Engineering...
# 10                                                None
# 11                                                None
# 12                                                None
# 13                                                None
# 14                                                None
# 15                                                None
# 16                                                None
# 17
# 18
# 19                                                None
# 20                                                None
# 21                                            Start.ng
# 22                                                None
# 23                       Hng, Html, Technology, Github
# 24                                                None
# 25                               Technology, Intership
# 26                                                None
# 27                                                None
# 28                                                None
# 29                                                None
# ..                                                 ...
# 846                                               None
# 847                       Technology, Sports, Politics
# 848                                         Technology
# 849                                         Technology
# 850
# 851                                               None
# 852
# 853
# 854
# 855
# 856
# 857
# 858
# 859
# 860                                               None
# 861                                               None
# 862                                         Technology
# 863                                             Health
# 864                                               None
# 865                                               None
# 866                                               None
# 867                                               None
# 868
# 869
# 870                                               None
# 871                                               None
# 872                                   Politics, Sports
# 873
# 874
# 875
#
#                                                   slug          created_at  \
# 0                what-i-have-learnt-so-far-on-html-985 2019-08-25 18:39:01
# 1                                 html-begins-here-4d6 2019-08-25 18:44:36
# 2                          my-laziness-in-the-open-029 2019-08-25 18:50:33
# 3                                        my-task-2-649 2019-08-25 18:51:36
# 4                                           task-2-7e5 2019-08-25 18:51:39
# 5                               my-journey-on-html-ce5 2019-08-25 18:54:07
# 6                          startng-html-exposition-4d5 2019-08-25 18:55:20
# 7                                        my-task-2-649 2019-08-25 18:57:59
# 871 2019-09-05 15:38:18                                       None      None
# 872 2019-09-06 13:39:26                                                 None
# 873 2019-09-06 13:39:26        jeff.ogah/images/img-07flurib94.png      None
# 874 2019-09-06 13:39:26       jeff.ogah/images/img-x89tf05exw.jpeg      None
# 875 2019-09-06 13:39:26                                                 None
#
#       action post_id
# 0       None    None
# 1       None    None
# 2       None    None
# 3       None    None
# 4       None    None
# 5       None    None
# 6       None    None
# 7       None    None
# 8       None    None
# 9       None    None
# 10      None    None
# 11      None    None
# 12      None    None
# 13      None    None
# 14      None    None
# 15      None    None
# 16      None    None
# 17      None    None
# 18      None    None
# 19      None    None
# 20      None    None
# 21      None    None
# 22      None    None
# 23      None    None
# 24      None    None
# 25      None    None
# 26      None    None
# 27      None    None
# 28      None    None
# 29      None    None
# ..       ...     ...
# 846     None    None
# 847     None    None
# 848     None    None
# 849     None    None
# 850     None    None
# 851     None    None
# 852     None    None
# 853     None    None
# 854     None    None
# 855     None    None
# 856     None    None
# 857     None    None
# 858     None    None
# 859     None    None
# 860     None    None
# 861     None    None
# 862    draft    None
# 863     None    None
# 864     None    None
# 865     None    None
# 866  publish    None
# 867  publish    None
# 868     None    None
# 869     None    None
# 870  publish    None
# 871  publish    None
# 872     None    None
# 873     None    None
# 874     None    None
# 875     None    None
#
# [876 rows x 12 columns]

# %%
#checking out the thoughts table
thoughts= pd.read_sql_query('select * from thoughts', engine)
thoughts
# Out:
#     id  user_id                                            content  \
# 0    1     2195                                           hhhhhhhh
# 1    2      148                      Can't believe I'm learning ML
# 2    3     2212  - what you have learned so far\r\nI've learned...
# 3    4        1                                         Hey people
# 4    5     2223                                               nice
# 5    6     2223                        <?php\r\necho "nice";\r\n?>
# 6    7        6                          It's one of those days...
# 7    8        6                                                TMI
# 8    9        4                                         Hey people
# 9   10     2263  No matter what happens in  your journey, make ...
# 10  11        6                                 I hate web design!
# 11  12     2278  I've been having so much to do recently and th...
# 12  13     2273  A FUTURE WITHOUT TEARS\r\nIt is possible, ther...
# 13  14        1                                                Hey
# 14  15        1                                            Testing
# 15  16        4                                                Hey
#
#             created_at          updated_at
# 0  2019-08-26 12:30:26 2019-08-26 12:30:26
# 1  2019-08-26 12:57:35 2019-08-26 12:57:35
# 2  2019-08-26 13:35:41 2019-08-26 13:35:41
# 3  2019-08-26 14:12:07 2019-08-26 14:12:07
# 4  2019-08-26 14:24:55 2019-08-26 14:24:55
# 5  2019-08-26 14:25:07 2019-08-26 14:25:07
# 6  2019-08-26 20:08:43 2019-08-26 20:08:43
# 7  2019-08-26 20:50:06 2019-08-26 20:50:06
# 8  2019-08-26 21:29:07 2019-08-26 21:29:07
# 9  2019-08-27 03:42:45 2019-08-27 03:42:45
# 10 2019-08-27 08:23:35 2019-08-27 08:23:35
# 11 2019-08-27 10:27:04 2019-08-27 10:27:04
# 12 2019-08-27 11:10:19 2019-08-27 11:10:19
# 13 2019-08-31 10:59:10 2019-08-31 10:59:10
# 14 2019-08-31 17:41:47 2019-08-31 17:41:47
# 15 2019-09-05 16:19:25 2019-09-05 16:19:25

# %%
#checking out the user_settings table
user_settings= pd.read_sql_query('select * from user_settings', engine)
user_settings
# Out:
#    id  user_id user_path setting_path          created_at          updated_at  \
# 0   1        4        4/              2019-09-22 20:34:42 2019-09-22 20:34:42
# 1   2        2        2/              2019-09-23 04:51:40 2019-09-23 04:51:40
#
#    tabs      view    theme public_view
# 0  None  Timeline  default        Home
# 1  None  timeline  default        Home

# %%
#checking out the user_settings table
users = pd.read_sql_query('select * from users', engine)
users
# Out:
#         id                         name                username  \
# 0        1           Eniayomi Oluwaseyi                eniayomi
# 1        2                Elijah Okokon                 DMatrix
# 2        3                 Jeffrey Ogah               jeff.ogah
# 3        4        Oluwaseyi Oluwapelumi                  nathan
# 4        5                         PoRH                   lamar
# 5        6                 Seyi Onifade                   xyluz
# 6        7                  Mark Essien              markessien
# 7        8                   Alex Moses              ahlesswywk
# 8        9                 Edmund Ekott             26th_edmund
# 9       10                   Stefan aGz            stefanpongrz
# 10      11                 Jenni Essien             j.naiaretti
# 11      12                 Amujo Samuel             samuelamujo
# 12      13        Olatunbosun Egberinde                bosunski
# 13      14               Habeeb Shopeju                shopejuh
# 14      15               Patrick Aziken                onaziken
# 15      16                  David Saint             topstronics
# 16      17                  Jane Arisah               jarish001
# 17      18               Wisdom Anthony             wizitendo10
# 18      19                  Lawal Idris             idriseun222
# 19      20                  albert oboh            albidosurest
# 20      21                  Samuel Weke             samuelsweke
# 21      22                  Godspeed Ps             godspeed.gp
# 22      23          Oluwatomisin Lalude        oluwatomisin1605
# 23      24                 Paul Stylish          stylishpaul.ps
# 24      25                Abraham Ebuka               buka4rill
# 25      26            Everistus Olumese        everistusolumese
# 26      27              Chigozie Ekwonu                 chygoz2
# 27      28                  Kelvin Pere            perekelvin66
# 28      29                  Lucid Lucid         lucidowner.test
# 29      30                  local caleb          localcalebman2
# ...    ...                          ...                     ...
# 2263  2268           adeleye olanrewaju  adeleye.olanrewaju1234
# 2264  2269               Adenrele Cuduz         adenrelealcuduz
# 2265  2270            BRENDAN DEVELOPER         brendandevelops
# 2266  2271                  elijah leke                adeleked
# 2267  2272                  Dayo Yusuff              yusuffdayo
# 2268  2273             Vick Greenfields             akintoluvic
# 2269  2274          Benedicta Nwachukwu          benedictanwa19
# 2270  2275                collins chuwa            collinschuwa
# 2271  2276              Chioma Florence          florencechioma
# 2272  2277                Abubakar Imam                xabuimam
# 2273  2278           Johnbosco Nduaguba       johnbosconduaguba
# 2274  2279                 UTIBE BASSEY          bassey.utibe22
# 2275  2280  Feyisayo Anthonia Famakinde               thetonina
# 2276  2281              prevailer akpan          akpanprevailer
# 2277  2282                         Jimi                    Jimi
# 2278  2283                Affiong Okoko            affiongokoko
# 2279  2284             Adekola Toniloba               atoniloba
# 2280  2285              Onyinyechi Gift       onyinyechigift146
# 2281  2286                Kayode Joseph                kayodej4
# 2282  2287            Goodness Afonughe               goodnerda
# 2265 2019-08-27 08:37:07                                               None
# 2266 2019-08-27 08:37:46                                               None
# 2267 2019-08-27 08:47:49                                               None
# 2268 2019-08-27 09:09:13                                             My Bio
# 2269 2019-08-27 09:21:47                                            JUST ME
# 2270 2019-08-27 09:24:57                                               None
# 2271 2019-08-27 09:25:31            I wish to make the world a better place
# 2272 2019-08-27 09:41:34                                               None
# 2273 2019-08-27 09:50:00  Technology and automobile enthusiast with an u...
# 2274 2019-08-27 10:12:23                                               None
# 2275 2019-08-27 10:30:12                                               None
# 2276 2019-08-27 10:37:30                                               None
# 2277 2019-08-27 10:38:40                                               None
# 2278 2019-08-27 11:05:13                                               None
# 2279 2019-08-27 11:13:48                                               None
# 2280 2019-08-27 11:25:43                                               None
# 2281 2019-08-27 11:38:36                                               None
# 2282 2019-08-27 12:20:32                                               None
# 2283 2019-08-27 12:34:13                                               None
# 2284 2019-08-27 13:17:54                                               None
# 2285 2019-08-27 13:52:39                                               None
# 2286 2019-08-27 14:13:09  I am deeply passionate about doing what i do a...
# 2287 2019-08-27 14:27:57                                               None
# 2288 2019-08-27 15:41:27                                               None
# 2289 2019-08-27 15:47:31  A web developer enthusiasts. Looking forward t...
# 2290 2019-08-27 16:01:58                                               None
# 2291 2019-08-27 16:18:02                                               None
# 2292 2019-08-27 17:19:55                                               None
#
# [2293 rows x 12 columns]

# %%
#checking out the users_email_login_tokens table
users_email_login_tokens= pd.read_sql_query('select * from users_email_login_tokens', engine)
users_email_login_tokens
# Out:
# Empty DataFrame
# Columns: [id, user_id, token, created_at, updated_at]
# Index: []

# %%
#checking for relevant keys in the users dataframe
users.keys()
# Out:
# Index(['id', 'name', 'username', 'email', 'image', 'provider', 'provider_id',
#        'password', 'remember_token', 'created_at', 'updated_at', 'short_bio'],
#       dtype='object')

# %%
#checking for relevant keys in the posts dataframe
posts.keys()
# Out:
# Index(['id', 'user_id', 'title', 'content', 'tags', 'slug', 'created_at',
#        'updated_at', 'image', 'status_id', 'action', 'post_id'],
#       dtype='object')

# %%
#checking the shape of our users and posts dataframe
users.shape,posts.shape
# Out:
# ((2293, 12), (876, 12))

# %%
users['short_bio'].value_counts()
# Out:
# Web Developer                                                                                                                                          8
# Tech Enthusiast                                                                                                                                        6
# Software Developer                                                                                                                                     6
# Front End Developer                                                                                                                                    4
# Software Engineer                                                                                                                                      4
# Backend Developer                                                                                                                                      4
# Software developer                                                                                                                                     3
# Android Developer                                                                                                                                      3
# Aspiring Developer                                                                                                                                     3
# Tech enthusiast                                                                                                                                        3
# Relentless learner                                                                                                                                     2
# Frontend developer                                                                                                                                     2
# Learner.                                                                                                                                               2
# Aspiring Digital Marketer                                                                                                                              2
# Aspiring front end developer                                                                                                                           2
# Backend developer                                                                                                                                      2
# Tech Lover                                                                                                                                             2
# Developer                                                                                                                                              2
# Web developer                                                                                                                                          2
# Student                                                                                                                                                2
# Frontend Web Developer                                                                                                                                 2
# A front end developer                                                                                                                                  2
# Front-end developer                                                                                                                                    2
# Always learning                                                                                                                                        2
# Digital Marketing                                                                                                                                      2
# Aspiring full stack developer                                                                                                                          2
# Front-End Developer                                                                                                                                    2
# Hello World                                                                                                                                            2
# Aspiring Front End Developer                                                                                                                           2
# HNG pre-internship program                                                                                                                             1
#                                                                                                                                                       ..
# Your next big technocrat. Tech lover, Chess and table tennis player....                                                                                1
# Emerging Web Developer.                                                                                                                                1
# A budding front end dev                                                                                                                                1
# your everyday bad guy with mad skills in creative writing and too i am your next boyfriend, did even tell you i want to be a 10s web developer.        1
# An optimist with keen interest in human capital and mental wealth.                                                                                     1
# I'm a designer                                                                                                                                         1
# I'm just a simple girl in love with her creator, a tech enthusiast and I guess I know a little about a whole lot of things. Don't try me               1
# Animator || OAU.\r\n\r\n             \r\n  Aspiring Mobile App Development                                                                             1
# Aspiring developer.                                                                                                                                    1
# I write, eat, digest and live by code.                                                                                                                 1
# A data geoscientist, a renewable energy social investor and an explorer into the digital space                                                         1
# A forward looking frontend developer                                                                                                                   1
# I am a Front End Web Developer                                                                                                                         1
# Android App Developer, Tech Enthusiast, Average Gamer                                                                                                  1
# Software Developer: Ussd specialist, js (Angular, svelte),  php (laravel, Codeigniter), python(django).                                                1
# I'm a mobile app developer & UI/UX enthusiast                                                                                                          1
# I see myself becoming an Andelan and a HNG Internship finalist                                                                                         1
# I am Ogbu Casmir Chika by name.\r\nI am an aspiring full stack software developer...                                                                   1
# I am Sam, aspiring full stack web developer,and I'm enthusiast  \r\nI love everything relating to programming                                          1
# I'm a learner                                                                                                                                          1
# Intern at Start.ng                                                                                                                                     1
# I am passionately learning web and app development in order to impact Nigeria, Africa and the world at large. I am currently a pre-intern with HNG.    1
# Hello, I am Paul E. Okonko, MNSE currently based in Port Harcourt and have passion for computing.                                                      1
# Earger to learn, beautiful heart, dedicated and hard-working                                                                                           1
# Story teller\r\nSoftware developer\r\nEngineer                                                                                                         1
# Innovation is intriguing, Hardwork is necessary and Investment is a basic futuristic plan                                                              1
# Digital Marketer and coder in the making                                                                                                               1
# I provide soundtracks to the timeless moments of live.                                                                                                 1
# I'm simple and fun to be with.\r\nLover of nature.                                                                                                     1
# an Individual with passion in Information Technology                                                                                                   1
# Name: short_bio, Length: 1390, dtype: int64

# %%
posts['title'].value_counts()
# Out:
# HNG Task 2                                                                       10
# Learning HTML with StartNG                                                       10
# WHAT I HAVE LEARNT SO FAR                                                         9
# THE RELATION BETWEEN HTML AND CSS                                                 9
# My First Language!!                                                               7
# My Coding Diary                                                                   6
# Another update from your starry-eyed programmer: Creating a CV with HTML only     6
# task 2                                                                            6
# StartNG Task Two - Creating a CV using only HTML                                  5
# All About HTML                                                                    5
# CSS Rules                                                                         5
# Taking Baby Steps in Web Development at StartNG                                   5
# Task 2                                                                            4
# Moodle for Africa in Coted'ivoire                                                 4
# CSS is a Whole new Level                                                          4
# HTML                                                                              4
# Start.Ng, My journey so far part 1                                                4
# My journey so far....                                                             4
# curriculum vitae                                                                  4
# My Expertise.                                                                     4
# BUILD AROUND YOUR DISCOVERY MECHANISM                                             3
# Journey so far....                                                                3
# Hints To My Lesson (HTML) so far                                                  3
# Journey so far                                                                    3
# Five days of Learning HTML at StartNg                                             3
# MY HTML EXPERIENCE                                                                3
# Styling with CSS                                                                  3
# TASK 2                                                                            3
# The Journey So Far                                                                3
# ON YOUR TRACK...SET...GO: ON THE LONG ROAD TO SOFTWARE DEVELOPMENT                3
#                                                                                  ..
# MY HTML TASK                                                                      1
# MY ADVANCEMENT                                                                    1
# How CSS Made My HTML Page Looks CLean                                             1
# What would become of me?                                                          1
# Task 4 (sub task 7)                                                               1
# My StartNG Pre-internship Experience                                              1
# Greatness is within                                                               1
# what i have learned at Start.NG                                                   1
# MY HNG EXPERIENCE                                                                 1
# A Trip To Iceland                                                                 1
# MY JOURNEY SO FAR                                                                 1
# What I done so far                                                                1
# CLASS HAS STARTED                                                                 1
# Your face PHP script                                                              1
# STARTNG AND HTML TUTORIAL                                                         1
# Failing is okay.                                                                  1
# What you have learned so far                                                      1
# How did your day go?                                                              1
# EVALUATING STARTUP IDEAS                                                          1
# HNG Thoughts                                                                      1
# HNG Internship and Start.ng Pre-Internship task                                   1
# Hng internship                                                                    1
# THOSE FIRST HTML CODES.....NOT AS EASY AS IT SEEMS                                1
# HNG Pre-Internship 6.0 - Gideon's Learning Timeline                               1
# What comes to mind when you hear &quot;Hello World&quot;                          1
# TEst                                                                              1
# What have done so far on HTML                                                     1
# My First Week in the StartNG Bootcamp                                             1
# Start Task Two : My Resume                                                        1
# My Experience at STARTNG...                                                       1
# Name: title, Length: 658, dtype: int64

# %% [markdown]
# # Data Wrangling

# %%
# Remove html tags
posts['content'] = posts['content'].str.replace(r'<[^>]*>', '')

# Remove white spaces including new lines
posts['content'] = posts['content'].str.replace(r'\s', ' ')

# Remove square brackets
posts['content'] = posts['content'].str.replace(r'\[.*?\]', '')

# Remove image files
posts['content'] = posts['content'].str.replace(r'\(.*?\)', '')

# %% [markdown]
# # BUILDING THE "WHO TO FOLLOW" RECOMMENDER SYSTEM

# %%
#importing relevant modules
import pandas as pd
from sklearn.metrics.pairwise import linear_kernel
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
lucid_tfidf = TfidfVectorizer(stop_words='english')
# filling the missing values with empty string
users['short_bio'] = users['short_bio'].fillna('')
# computing TF-IDF matrix required for calculating cosine similarity
users_short_bio_matrix = lucid_tfidf.fit_transform(users['short_bio'])

# %%
users_short_bio_matrix.shape
# Out:
# (2293, 2242)

# %%
#calculating the cosine similarity for our users_short_bio_matrix 
cosine_similarity = linear_kernel(users_short_bio_matrix, users_short_bio_matrix)
#getting our user indices
user_indices = pd.Series(users['name'].index)

# %%
#function to recommend user to follow based on similarities in their short_bio
def recommend_to_follow(index, cosine_sim=cosine_similarity):
    if index<users_short_bio_matrix.shape[0]:
        id = user_indices[index]
        # Get the pairwsie similarity scores of all names
        # sorting them and getting top 5
        similarity_scores = list(enumerate(cosine_sim[id]))
        similarity_scores = sorted(similarity_scores, key=lambda x: x[1], reverse=True)
        similarity_scores = similarity_scores[1:6]
        
        # Get the names index
        lucid_index = [i[0] for i in similarity_scores]
        # Return the top 5 most similar names
        return users['name'].iloc[lucid_index]
    else: return "No recommedations for this user"

# %% [markdown]
# # TESTING THE RECOMMENDER SYSTEM

# %%
recommend_to_follow(50)
# Out:
# 105     Damilare Olabimtan
# 279        UDENKWOR NKECHI
# 438         Angela Egerega
# 604    chukwuemeka anyanwu
# 641          Deborah Ajayi
# Name: name, dtype: object

# %%
recommend_to_follow(245)
# Out:
# 480         Marylyn Idomo
# 721     Ogunlaja Oreoluwa
# 109        Ifeoluwa Aminu
# 1684       Ndonna Ugwuede
# 24          Abraham Ebuka
# Name: name, dtype: object

# %%
recommend_to_follow(2456)
# Out:
# 'No recommedations for this user'

# %%
recommend_to_follow(750)
# Out:
# 1            Elijah Okokon
# 2             Jeffrey Ogah
# 3    Oluwaseyi Oluwapelumi
# 4                     PoRH
# 5             Seyi Onifade
# Name: name, dtype: object

# %% [markdown]
# # BUILDING THE "WHAT ARTICLES TO READ" RECOMMENDER SYSTEM

# %%
lucids_tfidf = TfidfVectorizer(stop_words='english')
# filling the missing values with empty string
posts['content'] = posts['content'].fillna('')
# computing TF-IDF matrix required for calculating cosine similarity
posts_matrix = lucids_tfidf.fit_transform(posts['content'])

# %%
#checking the shape of our posts matrix
posts_matrix.shape
# Out:
# (876, 4597)

# %%
#calculating the cosine similarity for our posts_matrix
cosines_similarity = linear_kernel(posts_matrix, posts_matrix)
#getting our post indices
posts_indices = pd.Series(posts['title'].index)

# %%
#function to recommend user to follow based on similarities in their short_bio
def recommend_article_to_read(index, cosine_sim=cosines_similarity):
    if index<posts_matrix.shape[0]:
        id = posts_indices[index]
        # Get the pairwsie similarity scores of all names
        # sorting them and getting top 5
        similarity_scores = list(enumerate(cosine_sim[id]))
        similarity_scores = sorted(similarity_scores, key=lambda x: x[1], reverse=True)
        similarity_scores = similarity_scores[1:6]
        # Get the names index
        lucid_index = [i[0] for i in similarity_scores]
        # Return the top 5 most similar names
        return posts['title'].iloc[lucid_index]
    else: return "No recommedations for this user"

# %% [markdown]
# # TESTING THE RECOMMENDER SYSTEM

# %%
recommend_article_to_read(24)
# Out:
# 529                            MY HNG Internship Journey
# 448    What comes to mind when you hear &quot;Hello W...
# 303                                       startNG Task 2
# 379      What I have Learnt so far in StartNG Internship
# 432                                   My learning so far
# Name: title, dtype: object

# %%
recommend_article_to_read(34567)
# Out:
# 'No recommedations for this user'

# %%
recommend_article_to_read(345)
# Out:
# 346    DAY 2: HTML CLASS (HNG PRE-INTERNSHIP PROGRAM)
# 102                         WHAT I HAVE LEARNT SO FAR
# 103                         WHAT I HAVE LEARNT SO FAR
# 104                         WHAT I HAVE LEARNT SO FAR
# 105                         WHAT I HAVE LEARNT SO FAR
# Name: title, dtype: object

# %%
recommend_article_to_read(800)
# Out:
# 316                               My Programming Journey
# 310                              The Pre-Internship Tour
# 16     The Journey with StartNG: Creating my CV with ...
# 25                                      StartNg Task One
# 450                              So far with StartNG ...
# Name: title, dtype: object

# %%
recommend_article_to_read(5604)
# Out:
# 'No recommedations for this user'
